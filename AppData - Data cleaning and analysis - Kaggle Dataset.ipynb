# %% [markdown]
# # Analyzing Profitable Apps for Google Play Store and iOS App Store

# %% [markdown]
# ## Objective
#
# The goal of this project is to analyse the marketplace for Profitable Apps on iOS Store and Google Play Store. This notebook is created from the perspective of a Data Analyst who is working for a company that specialises in creating Mobile Apps.
#
# We are trying to help the App Developers of our company make data-driven business decisions as to what type of app they should start developing, the target audience and other factors that would define how much feasible resources need to be put in to create a free app that generates revenue through in-app ads.
#
# We need to find a niche which has the optimum traffic and screen-time to have maximum number of customers engaging with the ads within our app. At the same time, it should not be dominated by apps that are hard to compete against or that do not saturate the market genre so much that there are hardly any customers who choose alternatives to these apps.

# %% [markdown]
# ## Data
#
# The first task would be to scrape or find data for these two App Stores with relevant information like app name, size, price, rating, number of reviews, number of installs etc.
# For better cost management, the first approach would be to find any readily available datasets on the web that we can use.
# Luckily for us, there are two Kaggle datasets that have the type of app data that we need.
#
# 1. [Google Play Store Dataset](https://www.kaggle.com/datasets/lava18/google-play-store-apps?resource=download) containing a scraped dataset of 10K apps from the Play Store.
#
# 2. [iOS App Store Dataset](https://www.kaggle.com/datasets/ramamet4/app-store-apple-data-set-10k-apps) containing a scraped dataset of 7K apps from the iOS Mobile App Store.

# %% [markdown]
# ### Reading the dataset
# Open the two datasets and instantiate them as list of lists. Create a function `explore_data` to explore the dataset so we don't have to write code to print the data whenever we need to explore it.

# %%
from csv import reader
import numpy as np

file_1 = reader(open('App_Dataset/AppleStore.csv', encoding = 'utf8'))           # Open and read datasets and create a list
applestore = list(file_1)

file_2 = reader(open('App_Dataset/googleplaystore.csv', encoding = 'utf8'))
playstore = list(file_2)

applestore_header = applestore[0]                                               # Isolate the header rows
applestore = applestore[1:]

playstore_header = playstore[0]
playstore = playstore[1:]

# %%
def explore_data(data, start, end, rows_columns = False):     # defines four parameters to execute the function
    data_slice = data[start:end]                              # creates a small printable slice of the dataset
    for row in data_slice:
        print(row)
        print('\n')                                           # print the selected rows
    if rows_columns:
        print('Number of rows:', len(data))
        print('Number of columns:', len(data[0]))             #print the number of rows and columns if desired

# %%
print(applestore_header,'\n')
explore_data(applestore,0,3,True)
# Out:
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
#
#
# ['3', '281940292', 'WeatherBug - Local Weather, Radar, Maps, Alerts', '100524032', 'USD', '0', '188583', '2822', '3.5', '4.5', '5.0.0', '4+', 'Weather', '37', '5', '3', '1']
#
#
# Number of rows: 7197
# Number of columns: 17

# %% [markdown]
# We have 7197 iOS apps in this data set, and the columns that seem interesting are: `track_name`, `currency`, `price`, `rating_count_tot`, `rating_count_ver`, and `prime_genre`. Not all column names are self-explanatory in this case, but details about each column can be found in the data set [documentation](https://www.kaggle.com/datasets/ramamet4/app-store-apple-data-set-10k-apps).

# %%
print(playstore_header,'\n')
explore_data(playstore,0,3,True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %% [markdown]
# We see that the Google Play Store data set has 10841 apps and 13 columns. At a quick glance, the columns that might be useful for the purpose of our analysis are `App`, `Category`, `Reviews`, `Installs`, `Type`, `Price`, and `Genres`.

# %% [markdown]
# ## Data Wrangling
#
# Now after gaining an insight to the format of our data and examples to its entries. We have an overview of our datasets and can begin the next phase of our project. Data Wrangling is an important role in any Data Analyst's work. The cleaner and more uniform the data is, the easier it is to analyse it.
#
# We can always come back and create more cleaning procedures if there are any errors encountered during the analysis part.

# %% [markdown]
# ### Missing or incomplete data
#
# Create a function to delete incomplete entries causing column shift inside a row.

# %%
def delete_incomplete(dataset,dataset_header):
    for row in dataset:
        i = 0                                                       # denotes the regular iteration of the for loop 
        n = 0                                                       # denotes the iteration increment when a deletion is made
        row_len = len(row)
        if row_len != len(dataset_header):
            del dataset[i-n]                                        # helps compensate the index after each deletion
            n = n+1
        i = i+1

# %%
print('Rows before deletion:',len(playstore))
delete_incomplete(playstore,playstore_header)
print('Rows after deletion:',len(playstore))
# Out:
# Rows before deletion: 10841
# Rows after deletion: 10840

# %% [markdown]
# There was one row in this dataset which had discrepancies with its entries that would cause the row to have less number of columns. This might seem a very redundant procedure in this case but it is a necessary one. This would help avoid any errors that we would have encountered trying to convert our list of lists into a Pandas DataFrame.

# %%
print('Rows before deletion:',len(applestore))
delete_incomplete(applestore,applestore_header)
print('Rows after deletion:',len(applestore))
# Out:
# Rows before deletion: 7197
# Rows after deletion: 7197

# %% [markdown]
# There were no incomplete rows in this dataset and we can move forwards with next steps of our data cleaning procedure.

# %% [markdown]
# ### Deleting duplicate rows
#
# Duplication is very common in any dataset and is always a good practice to check for any duplicates and remove them. We do this in order to avoid any errors in our analysis that might skew the conclusion that we come to.
#
# We create two empty lists, all the apps will be added to the `unique_apps` list once. After which, if the same app name is encountered again it will be appended to the `duplicate_apps` list.

# %%
duplicate_apps = []
unique_apps = []

for row in playstore:
    name = row[0]
    if name in unique_apps:
        duplicate_apps.append(name)
    else:
        unique_apps.append(name)

# %%
print(len(duplicate_apps))
# Out:
# 1181

# %% [markdown]
# Google Play Store dataset has 1181 instances of duplication. This could mean 1181 different apps duplicated once, or a less number of apps with multiple entries.

# %%
duplicate_apps_unique = np.unique(duplicate_apps)
print(duplicate_apps[:30])

print('\n','Number of duplicate apps: ',len(duplicate_apps_unique))
# Out:
# ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack', 'FreshBooks Classic', 'Insightly CRM', 'QuickBooks Accounting: Invoicing & Expenses', 'HipChat - Chat Built for Teams', 'Xero Accounting Software', 'MailChimp - Email, Marketing Automation', 'Crew - Free Messaging and Scheduling', 'Asana: organize team projects', 'Google Analytics', 'AdWords Express', 'Accounting App - Zoho Books', 'Invoice & Time Tracking - Zoho', 'join.me - Simple Meetings', 'Invoice 2go — Professional Invoices and Estimates', 'SignEasy | Sign and Fill PDF and other Documents', 'Quick PDF Scanner + OCR FREE', 'Genius Scan - PDF Scanner', 'Tiny Scanner - PDF Scanner App', 'Fast Scanner : Free PDF Scan', 'Mobile Doc Scanner (MDScan) Lite']
#
#  Number of duplicate apps:  798

# %% [markdown]
# There are 798 apps with duplication. There would be a few apps with more than 2 duplication.

# %%
for row in playstore:
    name = row[0]
    if name in duplicate_apps[:3]:
        print(row)
        print('\n')
        
print(playstore_header)
# Out:
# ['Google My Business', 'BUSINESS', '4.4', '70991', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '2.19.0.204537701', '4.4 and up']
#
#
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
#
#
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
#
#
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Google My Business', 'BUSINESS', '4.4', '70991', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '2.19.0.204537701', '4.4 and up']
#
#
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Google My Business', 'BUSINESS', '4.4', '70991', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '2.19.0.204537701', '4.4 and up']
#
#
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80804', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
#
#
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %% [markdown]
# In most cases the duplicate entries are identical. The discrepancies appear in the `Reviews` column for some apps like Instagram.

# %%
for row in playstore:
    name = row[0]
    if name == "Instagram":
        print(row)
        print('\n')
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %% [markdown]
# The criteria to filter duplicate rows will be based on the `Reviews` column. The entry with the highest number of reviews would be the most recent updation. Therefore, that entry will be kept.

# %% [markdown]
# We will filter these duplicate apps by creating a dictionary with app name as the key and the maximum reviews that it has as its dictionary value.

# %%
maxreview_dict = {}

for row in playstore:
    name = row[0]
    reviews = float(row[3])
    if name not in maxreview_dict:
        maxreview_dict[name] = reviews                                        
    elif name in maxreview_dict and reviews > maxreview_dict[name]:
        maxreview_dict[name] = reviews
        
print(maxreview_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4144/1094427992.py in <module>
#       3 for row in playstore:
#       4     name = row[0]
# ----> 5     reviews = float(row[3])
#       6     if name not in maxreview_dict:
#       7         maxreview_dict[name] = reviews
#
# ValueError: could not convert string to float: '3.0M'

# %% [markdown]
# We encountered an error depicting 'M' being used in `Reviews` instead of numerically entering millions. Let's run a for loop to change each instance where this happens and turn it into numerical format.

# %%
for row in playstore:
    name = row[0]
    review = row[3]
    if "M" in review:
        review = float(review.split('M')[0])*1000000          # use the first element of the split list and convert into million
        row[3] = review

# %%
maxreview_dict = {}

for row in playstore:
    name = row[0]
    reviews = float(row[3])
    if name not in maxreview_dict:                                  # first instance of app entry with its reviews
        maxreview_dict[name] = reviews
    elif name in maxreview_dict and reviews > maxreview_dict[name]: # if second entry has higher reviews, replace value
        maxreview_dict[name] = reviews
        
#print(maxreview_dict)

# %% [markdown]
# After creating a dictionary with each app and its highest rating among the duplicate entry, we can use this dictionary to filter through our data and create a new list where only the row with reviews matching the `maxreview_dict` value will be kept.

# %%
playstore_unique = []
added_names = []

for row in playstore:
    name = row[0]
    review = float(row[3])
    if maxreview_dict[name] == review and name not in added_names:
        playstore_unique.append(row)
        added_names.append(name)

# %%
print(len(playstore_unique))
# Out:
# 9659

# %%
explore_data(playstore_unique,0,5,True)
# Out:
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# ['Smoke Effect Photo Maker - Smoke Editor', 'ART_AND_DESIGN', '3.8', '178', '19M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'April 26, 2018', '1.1', '4.0.3 and up']
#
#
# Number of rows: 9659
# Number of columns: 13

# %% [markdown]
# ### Removing Non-English apps

# %% [markdown]
# Use ASCII standard character which have encoding between 0 and 127. Use `ord()` function to find out the encoding number.
# We will define a function that provides a boolean output to whether the app name is english or not.

# %% [markdown]
# Since there are some apps with emojis and other special characters within the English apps. We will allow a maximum of three non-ASCII characters in our app name filtering. This will ensure no unnecessary loss of useful data.

# %%
def is_english(name):
    non_ascii = 0                                          # ascii counter that increases each time there ord() returns value
    for char in name:                                      # greater than 127.
        if ord(char) > 127:
            non_ascii += 1
    if non_ascii > 3:
        return False
    else:
        return True

# %%
print(is_english('Instachat 😜'))
print(is_english('爱奇艺PPS -《欢乐颂2》电视剧热播'))
print(is_english('Instagram'))
# Out:
# True
# False
# True

# %%
print(applestore[0][2])
# Out:
# PAC-MAN Premium

# %% [markdown]
# We have successfully created a function to filter out non-english apps while also keeping the apps that are in english but have a few special characters. Now this function can be used to remove the non-english apps from our unique apps dataset.

# %%
playstore_english = []
applestore_english = []

for row in playstore_unique:
    name = row[0]
    if is_english(name):
        playstore_english.append(row)

for row in applestore:
    name = row[2]
    if is_english(name):
        applestore_english.append(row)

explore_data(playstore_english,0,3,True)
print('\n')
explore_data(applestore_english,0,3,True)
# Out:
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# Number of rows: 9614
# Number of columns: 13
#
#
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
#
#
# ['3', '281940292', 'WeatherBug - Local Weather, Radar, Maps, Alerts', '100524032', 'USD', '0', '188583', '2822', '3.5', '4.5', '5.0.0', '4+', 'Weather', '37', '5', '3', '1']
#
#
# Number of rows: 6183
# Number of columns: 17

# %% [markdown]
# ### Isolating free apps
#
# The next step would be to filter only the apps that are free. Since our app development model leverages in-app ads to generate revenue. We need to remove paid apps from our datasets before starting our analysis.

# %%
playstore_final = []
for row in playstore_english:
    price = row[7]
    if price == '0':
        playstore_final.append(row)

# %%
len(playstore_final)
# Out:
# 8863

# %%
applestore_final = []
for row in applestore_english:
    price = row[5]
    if price == '0':
        applestore_final.append(row)

# %%
len(applestore_final)
# Out:
# 3222

# %% [markdown]
# The data wrangling procedure is now complete.
#
# The final dataset contains only free english apps and the dataset contains unique apps without any duplication.

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# As we mentioned in the introduction, our aim is to determine the kinds of apps that are likely to attract more users because our revenue is highly influenced by the number of people using our apps.
#
# To minimize risks and overhead, our validation strategy for an app idea is comprised of three steps:
#
# 1. Build a minimal Android version of the app, and add it to Google Play.
# 2. If the app has a good response from users, we then develop it further.
# 3. If the app is profitable after six months, we also build an iOS version of the app and add it to the App Store.
#
# This means finding genres which have scope on both the platforms.

# %% [markdown]
# ### Most common apps by genre
#
# We'll start by creating a function that generates a frequency table of the apps in each genre; convert it into percentage and sort it in a descending order. This would give us a clear picture of which genres have the most apps.

# %%
print(playstore_header,'\n')
explore_data(playstore_english,0,3,True)
print('\n',applestore_header,'\n')
explore_data(applestore_english,0,3,True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# Number of rows: 9614
# Number of columns: 13
#
#  ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
#
#
# ['3', '281940292', 'WeatherBug - Local Weather, Radar, Maps, Alerts', '100524032', 'USD', '0', '188583', '2822', '3.5', '4.5', '5.0.0', '4+', 'Weather', '37', '5', '3', '1']
#
#
# Number of rows: 6183
# Number of columns: 17

# %%
def freq_table_percent(dataset,index):                                          # Takes the dataset and index to create a
    genres_freq = {}                                                            # frequency table with
    total = len(dataset)
    for row in dataset:
        genre = row[index]
        if genre not in genres_freq:
            genres_freq[genre] = 1
        elif genre in genres_freq:
            genres_freq[genre] += 1                                             # create a frequency table
    genres_freq_percent = {}
    for key in genres_freq:
        genres_freq_percent[key] = round(((genres_freq[key])/total)*100,2)      # convert it into frequency percentage
    
    return sorted(genres_freq_percent.items(), key=lambda item: item[1], reverse = True)   # return a descending order table

# %%
ios_genre_freq = freq_table_percent(applestore_final,-5)
ios_genre_freq
# Out:
# [('Games', 58.16),
#  ('Entertainment', 7.88),
#  ('Photo & Video', 4.97),
#  ('Education', 3.66),
#  ('Social Networking', 3.29),
#  ('Shopping', 2.61),
#  ('Utilities', 2.51),
#  ('Sports', 2.14),
#  ('Music', 2.05),
#  ('Health & Fitness', 2.02),
#  ('Productivity', 1.74),
#  ('Lifestyle', 1.58),
#  ('News', 1.33),
#  ('Travel', 1.24),
#  ('Finance', 1.12),
#  ('Weather', 0.87),
#  ('Food & Drink', 0.81),
#  ('Reference', 0.56),
#  ('Business', 0.53),
#  ('Book', 0.43),
#  ('Navigation', 0.19),
#  ('Medical', 0.19),
#  ('Catalogs', 0.12)]

# %% [markdown]
# According to our sample dataset, more than half of the apps on iOS Store are based around gaming or for-fun apps.

# %%
freq_table_percent(playstore_final, 1)
# Out:
# [('FAMILY', 18.91),
#  ('GAME', 9.73),
#  ('TOOLS', 8.46),
#  ('BUSINESS', 4.59),
#  ('LIFESTYLE', 3.9),
#  ('PRODUCTIVITY', 3.89),
#  ('FINANCE', 3.7),
#  ('MEDICAL', 3.53),
#  ('SPORTS', 3.4),
#  ('PERSONALIZATION', 3.32),
#  ('COMMUNICATION', 3.24),
#  ('HEALTH_AND_FITNESS', 3.08),
#  ('PHOTOGRAPHY', 2.94),
#  ('NEWS_AND_MAGAZINES', 2.8),
#  ('SOCIAL', 2.66),
#  ('TRAVEL_AND_LOCAL', 2.34),
#  ('SHOPPING', 2.25),
#  ('BOOKS_AND_REFERENCE', 2.14),
#  ('DATING', 1.86),
#  ('VIDEO_PLAYERS', 1.79),
#  ('MAPS_AND_NAVIGATION', 1.4),
#  ('FOOD_AND_DRINK', 1.24),
#  ('EDUCATION', 1.16),
#  ('ENTERTAINMENT', 0.96),
#  ('LIBRARIES_AND_DEMO', 0.94),
#  ('AUTO_AND_VEHICLES', 0.93),
#  ('HOUSE_AND_HOME', 0.82),
#  ('WEATHER', 0.8),
#  ('EVENTS', 0.71),
#  ('PARENTING', 0.65),
#  ('ART_AND_DESIGN', 0.63),
#  ('COMICS', 0.62),
#  ('BEAUTY', 0.6)]

# %% [markdown]
# The category `FAMILY` in the Play Store dataset is a very vague and broad genre. We will be using another column, `Genres` in the playstore dataset, which has a broader range of genres given instead of the `Category` column. We do this to see if we can get a better insight into what each category means.

# %%
freq_table_percent(playstore_final,-4)
# Out:
# [('Tools', 8.45),
#  ('Entertainment', 6.07),
#  ('Education', 5.35),
#  ('Business', 4.59),
#  ('Lifestyle', 3.89),
#  ('Productivity', 3.89),
#  ('Finance', 3.7),
#  ('Medical', 3.53),
#  ('Sports', 3.46),
#  ('Personalization', 3.32),
#  ('Communication', 3.24),
#  ('Action', 3.1),
#  ('Health & Fitness', 3.08),
#  ('Photography', 2.94),
#  ('News & Magazines', 2.8),
#  ('Social', 2.66),
#  ('Travel & Local', 2.32),
#  ('Shopping', 2.25),
#  ('Books & Reference', 2.14),
#  ('Simulation', 2.04),
#  ('Dating', 1.86),
#  ('Arcade', 1.85),
#  ('Video Players & Editors', 1.77),
#  ('Casual', 1.76),
#  ('Maps & Navigation', 1.4),
#  ('Food & Drink', 1.24),
#  ('Puzzle', 1.13),
#  ('Racing', 0.99),
#  ('Libraries & Demo', 0.94),
#  ('Role Playing', 0.94),
#  ('Auto & Vehicles', 0.93),
#  ('Strategy', 0.91),
#  ('House & Home', 0.82),
#  ('Weather', 0.8),
#  ('Events', 0.71),
#  ('Adventure', 0.68),
#  ('Comics', 0.61),
#  ('Beauty', 0.6),
#  ('Art & Design', 0.59),
#  ('Parenting', 0.5),
#  ('Card', 0.45),
#  ('Casino', 0.43),
#  ('Trivia', 0.42),
#  ('Educational;Education', 0.39),
#  ('Board', 0.38),
#  ('Educational', 0.37),
#  ('Education;Education', 0.34),
#  ('Word', 0.26),
#  ('Casual;Pretend Play', 0.24),
#  ('Music', 0.2),
#  ('Entertainment;Music & Video', 0.17),
#  ('Puzzle;Brain Games', 0.17),
#  ('Racing;Action & Adventure', 0.17),
#  ('Casual;Brain Games', 0.14),
#  ('Casual;Action & Adventure', 0.14),
#  ('Arcade;Action & Adventure', 0.12),
#  ('Action;Action & Adventure', 0.1),
#  ('Educational;Pretend Play', 0.09),
#  ('Entertainment;Brain Games', 0.08),
#  ('Simulation;Action & Adventure', 0.08),
#  ('Board;Brain Games', 0.08),
#  ('Parenting;Education', 0.08),
#  ('Art & Design;Creativity', 0.07),
#  ('Educational;Brain Games', 0.07),
#  ('Casual;Creativity', 0.07),
#  ('Parenting;Music & Video', 0.07),
#  ('Education;Pretend Play', 0.06),
#  ('Education;Creativity', 0.05),
#  ('Role Playing;Pretend Play', 0.05),
#  ('Education;Brain Games', 0.03),
#  ('Entertainment;Creativity', 0.03),
#  ('Educational;Creativity', 0.03),
#  ('Adventure;Action & Adventure', 0.03),
#  ('Role Playing;Action & Adventure', 0.03),
#  ('Educational;Action & Adventure', 0.03),
#  ('Entertainment;Action & Adventure', 0.03),
#  ('Puzzle;Action & Adventure', 0.03),
#  ('Education;Action & Adventure', 0.03),
#  ('Education;Music & Video', 0.03),
#  ('Casual;Education', 0.02),
#  ('Music;Music & Video', 0.02),
#  ('Simulation;Pretend Play', 0.02),
#  ('Puzzle;Creativity', 0.02),
#  ('Sports;Action & Adventure', 0.02),
#  ('Board;Action & Adventure', 0.02),
#  ('Entertainment;Pretend Play', 0.02),
#  ('Video Players & Editors;Music & Video', 0.02),
#  ('Comics;Creativity', 0.01),
#  ('Lifestyle;Pretend Play', 0.01),
#  ('Art & Design;Pretend Play', 0.01),
#  ('Entertainment;Education', 0.01),
#  ('Arcade;Pretend Play', 0.01),
#  ('Art & Design;Action & Adventure', 0.01),
#  ('Strategy;Action & Adventure', 0.01),
#  ('Music & Audio;Music & Video', 0.01),
#  ('Health & Fitness;Education', 0.01),
#  ('Casual;Music & Video', 0.01),
#  ('Travel & Local;Action & Adventure', 0.01),
#  ('Tools;Education', 0.01),
#  ('Parenting;Brain Games', 0.01),
#  ('Video Players & Editors;Creativity', 0.01),
#  ('Health & Fitness;Action & Adventure', 0.01),
#  ('Trivia;Education', 0.01),
#  ('Lifestyle;Education', 0.01),
#  ('Card;Action & Adventure', 0.01),
#  ('Books & Reference;Education', 0.01),
#  ('Simulation;Education', 0.01),
#  ('Puzzle;Education', 0.01),
#  ('Adventure;Education', 0.01),
#  ('Role Playing;Brain Games', 0.01),
#  ('Strategy;Education', 0.01),
#  ('Racing;Pretend Play', 0.01),
#  ('Communication;Creativity', 0.01),
#  ('Strategy;Creativity', 0.01)]

# %% [markdown]
# This gives us a idea of what categories/genres have a good supply of apps already present. Whether the market is saturated for each category or not.
# Now we will look at what apps have the most users and compare it with the genre frequency tables to find a sweet spot for our app development.

# %% [markdown]
# For Google Play Store, this data is provided in the `Installs` columns. Since there is no such column in the Apple Store, we will use the `rating_count_tot` column as an alternate method of finding relative traffic on the apps per genre.

# %% [markdown]
# ### Popular apps sorted by genres
#
# #### iOS Store

# %%
print(applestore_header,'\n')
# Out:
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %%
ios_genre = freq_table_percent(applestore_final, -5)
ios_genre
# Out:
# [('Games', 58.16),
#  ('Entertainment', 7.88),
#  ('Photo & Video', 4.97),
#  ('Education', 3.66),
#  ('Social Networking', 3.29),
#  ('Shopping', 2.61),
#  ('Utilities', 2.51),
#  ('Sports', 2.14),
#  ('Music', 2.05),
#  ('Health & Fitness', 2.02),
#  ('Productivity', 1.74),
#  ('Lifestyle', 1.58),
#  ('News', 1.33),
#  ('Travel', 1.24),
#  ('Finance', 1.12),
#  ('Weather', 0.87),
#  ('Food & Drink', 0.81),
#  ('Reference', 0.56),
#  ('Business', 0.53),
#  ('Book', 0.43),
#  ('Navigation', 0.19),
#  ('Medical', 0.19),
#  ('Catalogs', 0.12)]

# %% [markdown]
# We loop through each genre in our frequency tables and add up the popularity of each app and the length of each genre. Then we print out a sorted version of this calculation, giving us the popularity index per each genre.

# %%
popular_per_genre_ios = {}
for row in ios_genre:
    genre = row[0]
    popularity = 0
    len_genre = 0
    for app in applestore_final:
        ratings = float(app[6])
        if app[-5] == genre:
            popularity += ratings
            len_genre += 1
    popular_per_genre_ios[genre] = popularity/len_genre
popular_per_genre_ios = sorted(popular_per_genre_ios.items(), key=lambda item: item[1], reverse = True)

# %%
popular_per_genre_ios
# Out:
# [('Navigation', 86090.33333333333),
#  ('Reference', 74942.11111111111),
#  ('Social Networking', 71548.34905660378),
#  ('Music', 57326.530303030304),
#  ('Weather', 52279.892857142855),
#  ('Book', 39758.5),
#  ('Food & Drink', 33333.92307692308),
#  ('Finance', 31467.944444444445),
#  ('Photo & Video', 28441.54375),
#  ('Travel', 28243.8),
#  ('Shopping', 26919.690476190477),
#  ('Health & Fitness', 23298.015384615384),
#  ('Sports', 23008.898550724636),
#  ('Games', 22788.6696905016),
#  ('News', 21248.023255813954),
#  ('Productivity', 21028.410714285714),
#  ('Utilities', 18684.456790123455),
#  ('Lifestyle', 16485.764705882353),
#  ('Entertainment', 14029.830708661417),
#  ('Business', 7491.117647058823),
#  ('Education', 7003.983050847458),
#  ('Catalogs', 4004.0),
#  ('Medical', 612.0)]

# %% [markdown]
# Let's check for saturated genres where apps supply is high whereas traffic per genre is not that significant.
# Also we need to check for genres that have big monopolies in them.
# As Data Analysts, we know one of the basic rules of statistics, i.e., the Pareto principle. Once an entity starts to dominate ~50% of the total sector, it will have a high tendency to keep dominating the market and increasing it's share.

# %% [markdown]
# Navigation and Social Networking apps can have a monopolised landscape. Lets confirm that by checking the apps with the most traffic in the first few genres.
# If the traffic is divided amongst a range of apps, that would be a suitable scenario for us.

# %%
popular_genres_ios = ['Navigation','Reference','Social Networking','Music','Weather','Book','Food & Drink']
for genres in popular_genres_ios:
    print('\n','Popular apps in', genres,'\n')
    for row in applestore_final:
        name = row[2]
        ratings = row[6]
        genre = row[-5]
        if genre == genres:
            print(name,': Ratings = ', ratings,)
# Out:
#  Popular apps in Navigation
#
# Waze - GPS Navigation, Maps & Real-time Traffic : Ratings =  345046
# Geocaching® : Ratings =  12811
# ImmobilienScout24: Real Estate Search in Germany : Ratings =  187
# Railway Route Search : Ratings =  5
# CoPilot GPS – Car Navigation & Offline Maps : Ratings =  3582
# Google Maps - Navigation & Transit : Ratings =  154911
#
#  Popular apps in Reference
#
# Bible : Ratings =  985920
# Dictionary.com Dictionary & Thesaurus : Ratings =  200047
# Dictionary.com Dictionary & Thesaurus for iPad : Ratings =  54175
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : Ratings =  18418
# Merriam-Webster Dictionary : Ratings =  16849
# Google Translate : Ratings =  26786
# Night Sky : Ratings =  12122
# WWDC : Ratings =  762
# Jishokun-Japanese English Dictionary & Translator : Ratings =  0
# 教えて!goo : Ratings =  0
# VPN Express : Ratings =  14
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : Ratings =  17588
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : Ratings =  4693
# Guides for Pokémon GO - Pokemon GO News and Cheats : Ratings =  826
# Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free : Ratings =  718
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : Ratings =  8535
# GUNS MODS for Minecraft PC Edition - Mods Tools : Ratings =  1497
# Real Bike Traffic Rider Virtual Reality Glasses : Ratings =  8
#
#  Popular apps in Social Networking
#
# Facebook : Ratings =  2974676
# LinkedIn : Ratings =  71856
# Skype for iPhone : Ratings =  373519
# Tumblr : Ratings =  334293
# Match™ - #1 Dating App. : Ratings =  60659
# WhatsApp Messenger : Ratings =  287589
# TextNow - Unlimited Text + Calls : Ratings =  164963
# Grindr - Gay and same sex guys chat, meet and date : Ratings =  23201
# imo video calls and chat : Ratings =  18841
# Ameba : Ratings =  269
# Weibo : Ratings =  7265
# Badoo - Meet New People, Chat, Socialize. : Ratings =  34428
# Kik : Ratings =  260965
# Qzone : Ratings =  1649
# Fake-A-Location Free ™ : Ratings =  354
# Tango - Free Video Call, Voice and Chat : Ratings =  75412
# MeetMe - Chat and Meet New People : Ratings =  97072
# SimSimi : Ratings =  23530
# Viber Messenger – Text & Call : Ratings =  164249
# Find My Family, Friends & iPhone - Life360 Locator : Ratings =  43877
# Weibo HD : Ratings =  16772
# POF - Best Dating App for Conversations : Ratings =  52642
# GroupMe : Ratings =  28260
# Lobi : Ratings =  36
# WeChat : Ratings =  34584
# ooVoo – Free Video Call, Text and Voice : Ratings =  177501
# Pinterest : Ratings =  1061624
# 知乎 : Ratings =  397
# Qzone HD : Ratings =  458
# Skype for iPad : Ratings =  60163
# LINE : Ratings =  11437
# QQ : Ratings =  9109
# LOVOO - Dating Chat : Ratings =  1985
# QQ HD : Ratings =  5058
# Messenger : Ratings =  351466
# eHarmony™ Dating App - Meet Singles : Ratings =  11124
# YouNow: Live Stream Video Chat : Ratings =  12079
# Cougar Dating & Life Style App for Mature Women : Ratings =  213
# Battlefield™ Companion : Ratings =  689
# Whisper - Share, Express, Meet : Ratings =  39819
# We Heart It - Fashion, wallpapers, quotes, tattoos : Ratings =  90414
# Followers - Social Analytics For Instagram : Ratings =  112778
# InsTrack for Instagram - Analytics Plus More : Ratings =  85535
# Followers + for Instagram - Follower Analytics : Ratings =  28633
# Timehop : Ratings =  49510
# Repost for Instagram : Ratings =  15185
# LINE PLAY - Your Avatar World : Ratings =  34677
# Nextdoor : Ratings =  14402
# Hangouts : Ratings =  36404
# FollowMeter for Instagram - Followers Tracking : Ratings =  11976
# Telegram Messenger : Ratings =  7573
# Chatous - Chat with new people : Ratings =  1609
# QQ International : Ratings =  274
# FireChat : Ratings =  1037
# Jodel : Ratings =  1193
# Wishbone - Compare Anything : Ratings =  20649
# Zenly - Locate your friends in realtime : Ratings =  427
# Tantan : Ratings =  235
# Flinch - Video Chat Staring Contest : Ratings =  2134
# botman - Real time video chat : Ratings =  7
# 豆瓣 : Ratings =  407
# Marco Polo Video Walkie Talkie : Ratings =  27662
# After School - Funny Anonymous School News : Ratings =  18482
# Highrise - Your Avatar Community : Ratings =  2011
# Quick Reposter - Repost, Regram and Reshare Photos : Ratings =  17694
# Kiwi - Q&A : Ratings =  1538
# Periscope - Live Video Streaming Around the World : Ratings =  6062
# Inke—Broadcast an amazing life : Ratings =  147
# Discord - Chat for Gamers : Ratings =  9152
# Candid - Speak Your Mind Freely : Ratings =  398
# Down To Lunch : Ratings =  2535
# SOMA Messenger : Ratings =  3232
# Rawr Messenger - Dab your chat : Ratings =  180
# Popcorn Buzz - Free Group Calls : Ratings =  281
# Chain: Collaborate On MyVideo Story/Group Video : Ratings =  35
# BestieBox : Ratings =  0
# Selfeo : Ratings =  366
# Followers Analysis Tool For Instagram App Free : Ratings =  4253
# Hey! VINA - Where Women Meet New Friends : Ratings =  719
# PlayStation®Messages : Ratings =  1918
# WhenToPost: Best Time to Post Photos for Instagram : Ratings =  158
# MATCH ON LINE chat : Ratings =  0
# Fiesta by Tango - Chat & Meet New People : Ratings =  885
# Houseparty - Group Video Chat : Ratings =  3991
# All Devices for WhatsApp - Messenger for iPad : Ratings =  682
# Peach — share vividly : Ratings =  727
# bit-tube - Live Stream Video Chat : Ratings =  0
# Miitomo : Ratings =  23965
# SoundCloud Pulse: for creators : Ratings =  240
# IAmNaughty – Dating App to Meet New People Online : Ratings =  463
# League of Legends Friends : Ratings =  420
# GhostCodes - a discovery app for Snapchat : Ratings =  1313
# live.ly - live video streaming : Ratings =  4145
# Live.me – Live Video Chat & Make Friends Nearby : Ratings =  14724
# BOO! - Video chat camera with filters & stickers : Ratings =  1805
# Google Allo — smart messaging : Ratings =  862
# Google Duo - simple video calling : Ratings =  1033
# Chat for Whatsapp - iPad Version : Ratings =  5060
# Chat for Pokemon Go - GoChat : Ratings =  500
# niconico ch : Ratings =  0
# Followers Analytics for Instagram - InstaReport : Ratings =  13914
# Monkey : Ratings =  3060
# LINE BLOG : Ratings =  0
# Mustknow - anonymous video Q&A : Ratings =  53
# CTFxCmoji : Ratings =  39
# Fam — Group video calling for iMessage : Ratings =  279
#
#  Popular apps in Music
#
# Pandora - Music & Radio : Ratings =  1126879
# Shazam - Discover music, artists, videos & lyrics : Ratings =  402925
# iHeartRadio – Free Music & Radio Stations : Ratings =  293228
# Deezer - Listen to your Favorite Music & Playlists : Ratings =  4677
# Sonos Controller : Ratings =  48905
# NRJ Radio : Ratings =  38
# radio.de - Der Radioplayer : Ratings =  64
# Spotify Music : Ratings =  878563
# SoundCloud - Music & Audio : Ratings =  135744
# Sing Karaoke Songs Unlimited with StarMaker : Ratings =  26227
# SoundHound Song Search & Music Player : Ratings =  82602
# Ringtones for iPhone & Ringtone Maker : Ratings =  25403
# Coach Guitar - Lessons & Easy Tabs For Beginners : Ratings =  2416
# TuneIn Radio - MLB NBA Audiobooks Podcasts Music : Ratings =  110420
# Magic Piano by Smule : Ratings =  131695
# QQ音乐HD : Ratings =  224
# The Singing Machine Mobile Karaoke App : Ratings =  130
# Bandsintown Concerts : Ratings =  30845
# PetitLyrics : Ratings =  0
# edjing Mix:DJ turntable to remix and scratch music : Ratings =  13580
# Smule Sing! : Ratings =  119316
# Amazon Music : Ratings =  106235
# AutoRap by Smule : Ratings =  18202
# My Mixtapez Music : Ratings =  26286
# Certified Mixtapes - Hip Hop Albums & Mixtapes : Ratings =  9975
# Karaoke - Sing Karaoke, Unlimited Songs! : Ratings =  28606
# Napster - Top Music & Radio : Ratings =  14268
# Musi - Unlimited Music For YouTube : Ratings =  25193
# UE BOOM : Ratings =  612
# Spinrilla - Mixtapes For Free : Ratings =  15053
# Google Play Music : Ratings =  10118
# Piano - Play Keyboard Music Games with Magic Tiles : Ratings =  1636
# Bose SoundTouch : Ratings =  3687
# DatPiff : Ratings =  2815
# Sounds app - Music And Friends : Ratings =  5126
# Smart Music: Streaming Videos and Radio : Ratings =  17
# Free Piano app by Yokee : Ratings =  13016
# Simple Radio - Live AM & FM Radio Stations : Ratings =  4787
# Trebel Music - Unlimited Music Downloader : Ratings =  2570
# TIDAL : Ratings =  7398
# Acapella from PicPlayPost : Ratings =  2487
# Medly - Music Maker : Ratings =  933
# Amazon Alexa : Ratings =  3018
# Music Freedom - Unlimited Free MP3 Music Streaming : Ratings =  1246
# PlayGround • Music At Your Fingertips : Ratings =  150
# Musical Video Maker - Create Music clips lip sync : Ratings =  320
# Free Music Play - Mp3 Streamer & Player : Ratings =  2496
# LiveMixtapes : Ratings =  555
# AmpMe - A Portable Social Party Music Speaker : Ratings =  1047
# NOISE : Ratings =  355
# YouTube Music : Ratings =  7109
# Ringtones for iPhone with Ringtone Maker : Ratings =  4013
# Music Memos : Ratings =  909
# Musicloud - MP3 and FLAC Music Player for Cloud Platforms. : Ratings =  2211
# Bose Connect : Ratings =  915
# Cloud Music Player - Downloader & Playlist Manager : Ratings =  319
# Remixlive - Remix loops with pads : Ratings =  288
# Free Music -  Player & Streamer  for Dropbox, OneDrive & Google Drive : Ratings =  46
# Boom: Best Equalizer & Magical Surround Sound : Ratings =  1375
# MP3 Music Player & Streamer for Clouds : Ratings =  329
# Nicki Minaj: The Empire : Ratings =  5196
# SongFlip - Free Music Streamer : Ratings =  5004
# Blocs Wave - Make & Record Music : Ratings =  158
# Music and Chill : Ratings =  135
# Free Music - MP3 Streamer & Playlist Manager Pro : Ratings =  13443
# BOSS Tuner : Ratings =  13
#
#  Popular apps in Weather
#
# WeatherBug - Local Weather, Radar, Maps, Alerts : Ratings =  188583
# The Weather Channel: Forecast, Radar & Alerts : Ratings =  495626
# AccuWeather - Weather for Life : Ratings =  144214
# MyRadar NOAA Weather Radar Forecast : Ratings =  150158
# The Weather Channel App for iPad – best local forecast, radar map, and storm tracking : Ratings =  208648
# Météo-France : Ratings =  24
# Yurekuru Call : Ratings =  53
# QuakeFeed Earthquake Map, Alerts, and News : Ratings =  6081
# Moji Weather - Free Weather Forecast : Ratings =  2333
# FEMA : Ratings =  128
# Weather Underground: Custom Forecast & Local Radar : Ratings =  49192
# JaxReady : Ratings =  22
# Hurricane Tracker WESH 2 Orlando, Central Florida : Ratings =  203
# Hurricane by American Red Cross : Ratings =  1158
# Weather & Radar : Ratings =  37
# WRAL Weather Alert : Ratings =  25
# Yahoo Weather : Ratings =  112603
# Weather Live Free - Weather Forecast & Alerts : Ratings =  35702
# NOAA Weather Radar - Weather Forecast & HD Radar : Ratings =  45696
# iWeather - World weather forecast : Ratings =  80
# Almanac Long-Range Weather Forecast : Ratings =  12
# TodayAir : Ratings =  0
# Weather - Radar - Storm with Morecast App : Ratings =  78
# Storm Radar : Ratings =  22792
# WarnWetter : Ratings =  0
# wetter.com : Ratings =  0
# Forecast Bar : Ratings =  375
# Freddy the Frogcaster's Weather Station : Ratings =  14
#
#  Popular apps in Book
#
# Kindle – Read eBooks, Magazines & Textbooks : Ratings =  252076
# OverDrive – Library eBooks and Audiobooks : Ratings =  65450
# Audible – audio books, original series & podcasts : Ratings =  105274
# BookShout: Read eBooks & Track Your Reading Goals : Ratings =  879
# ikouhoushi : Ratings =  0
# Dr. Seuss Treasury — 50 best kids books : Ratings =  451
# Weirdwood Manor : Ratings =  197
# Green Riding Hood : Ratings =  392
# HOOKED - Chat Stories : Ratings =  47829
# Color Therapy Adult Coloring Book for Adults : Ratings =  84062
# MangaTiara - love comic reader : Ratings =  0
# MangaZERO - comic reader : Ratings =  9
# 謎解き2016 : Ratings =  0
# 謎解き : Ratings =  0
#
#  Popular apps in Food & Drink
#
# OpenTable - Restaurant Reservations : Ratings =  113936
# Allrecipes Dinner Spinner : Ratings =  109349
# McDo France : Ratings =  22
# Starbucks : Ratings =  303856
# Lieferando.de : Ratings =  29
# Domino's Pizza USA : Ratings =  258624
# Lieferheld - Delicious food delivery service : Ratings =  29
# Bon Appetit : Ratings =  750
# Chefkoch - Rezepte, Kochen, Backen & Kochbuch : Ratings =  20
# Chick-fil-A : Ratings =  5665
# Postmates - Food Delivery, Faster : Ratings =  9519
# Open Food Facts : Ratings =  1
# 7-Eleven, Inc. : Ratings =  1356
# Nowait Guest : Ratings =  1625
# DoorDash - Food Delivery : Ratings =  25947
# SONIC Drive-In : Ratings =  1645
# Youmiam : Ratings =  9
# McDonald's : Ratings =  4050
# Deliveroo: Restaurant Delivery - Order Food Nearby : Ratings =  1702
# Outback : Ratings =  805
# Dunkin' Donuts - Get Offers, Coupons & Rewards : Ratings =  9068
# UberEATS: Uber for Food Delivery : Ratings =  17865
# Delish Eatmoji Keyboard : Ratings =  154
# Marmiton Twist : Ratings =  2
# Starbucks Keyboard : Ratings =  457
# Whataburger : Ratings =  197

# %% [markdown]
# #### Findings after analysis
#
# * Navigation apps have big players like Waze, Google Maps that attract all the users.
#
# * Reference apps mostly have traffic for apps like Bible or Dictionaries.
#
# * Social Networking apps also have monopoly from big players like Facebook, WhatsApp, Pinterest, Messenger etc. It would take up   a lot of resources to compete with and disrupt the market with these companies' presence in the market.
#
# * Music apps have traffic on Spotify, Pandora, SoundCloud adding the total to around 2 million users.
#
# * Since our objective is to develop a free app that monetizes on ads, weather apps are not a good niche. Since people dont         usually spend too much time on these apps.

# %% [markdown]
# - The only balanced traffic we can notice is in genres `Reference` and `Book`. This provides us with a good sector that we can target.
# However, we need to overlap this sector with Google Play Store as well; and confirm availability in this sector.

# %% [markdown]
# #### Popular apps in Google Play Store

# %%
print(playstore_header,'\n')
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %% [markdown]
# Using the same method as for the iOS Store dataset, we loop through each genre, create a popularity index based on `Installs`. Since the format of this column is of the type `1,000,000+`,`5,000,000+` etc., we will use the number as they are and remove the `+` sign.

# %%
google_genre = freq_table_percent(playstore_final,1)
google_genre
# Out:
# [('FAMILY', 18.91),
#  ('GAME', 9.73),
#  ('TOOLS', 8.46),
#  ('BUSINESS', 4.59),
#  ('LIFESTYLE', 3.9),
#  ('PRODUCTIVITY', 3.89),
#  ('FINANCE', 3.7),
#  ('MEDICAL', 3.53),
#  ('SPORTS', 3.4),
#  ('PERSONALIZATION', 3.32),
#  ('COMMUNICATION', 3.24),
#  ('HEALTH_AND_FITNESS', 3.08),
#  ('PHOTOGRAPHY', 2.94),
#  ('NEWS_AND_MAGAZINES', 2.8),
#  ('SOCIAL', 2.66),
#  ('TRAVEL_AND_LOCAL', 2.34),
#  ('SHOPPING', 2.25),
#  ('BOOKS_AND_REFERENCE', 2.14),
#  ('DATING', 1.86),
#  ('VIDEO_PLAYERS', 1.79),
#  ('MAPS_AND_NAVIGATION', 1.4),
#  ('FOOD_AND_DRINK', 1.24),
#  ('EDUCATION', 1.16),
#  ('ENTERTAINMENT', 0.96),
#  ('LIBRARIES_AND_DEMO', 0.94),
#  ('AUTO_AND_VEHICLES', 0.93),
#  ('HOUSE_AND_HOME', 0.82),
#  ('WEATHER', 0.8),
#  ('EVENTS', 0.71),
#  ('PARENTING', 0.65),
#  ('ART_AND_DESIGN', 0.63),
#  ('COMICS', 0.62),
#  ('BEAUTY', 0.6)]

# %%
popular_per_genre_google = {}
for row in google_genre:
    genre = row[0]
    popularity = 0
    len_genre = 0
    for app in playstore_final:
        installs = float(app[5].replace(',','').replace('+',''))
        if app[1] == genre:
            popularity += installs
            len_genre += 1
    popular_per_genre_google[genre] = round(popularity/len_genre,2)
popular_per_genre_google = sorted(popular_per_genre_google.items(), key=lambda item: item[1], reverse = True)

# %%
popular_per_genre_google
# Out:
# [('COMMUNICATION', 38456119.17),
#  ('VIDEO_PLAYERS', 24727872.45),
#  ('SOCIAL', 23253652.13),
#  ('PHOTOGRAPHY', 17840110.4),
#  ('PRODUCTIVITY', 16787331.34),
#  ('GAME', 15588015.6),
#  ('TRAVEL_AND_LOCAL', 13984077.71),
#  ('ENTERTAINMENT', 11640705.88),
#  ('TOOLS', 10801391.3),
#  ('NEWS_AND_MAGAZINES', 9549178.47),
#  ('BOOKS_AND_REFERENCE', 8767811.89),
#  ('SHOPPING', 7036877.31),
#  ('PERSONALIZATION', 5201482.61),
#  ('WEATHER', 5074486.2),
#  ('HEALTH_AND_FITNESS', 4188821.99),
#  ('MAPS_AND_NAVIGATION', 4056941.77),
#  ('FAMILY', 3695641.82),
#  ('SPORTS', 3638640.14),
#  ('ART_AND_DESIGN', 2021626.79),
#  ('FOOD_AND_DRINK', 1924897.74),
#  ('EDUCATION', 1833495.15),
#  ('BUSINESS', 1712290.15),
#  ('LIFESTYLE', 1437816.27),
#  ('FINANCE', 1387692.48),
#  ('HOUSE_AND_HOME', 1331540.56),
#  ('DATING', 854028.83),
#  ('COMICS', 817657.27),
#  ('AUTO_AND_VEHICLES', 647317.82),
#  ('LIBRARIES_AND_DEMO', 638503.73),
#  ('PARENTING', 542603.62),
#  ('BEAUTY', 513151.89),
#  ('EVENTS', 253542.22),
#  ('MEDICAL', 120550.62)]

# %%
popular_genres_google = ['COMMUNICATION','VIDEO_PLAYERS','SOCIAL','BOOKS_AND_REFERENCE']
for genres in popular_genres_google:
    print('\n','Popular apps in', genres,'\n')
    for row in playstore_final:
        name = row[0]
        installs = float(row[5].replace('+','').replace(',',''))
        genre = row[1]
        if genre == genres:
            print(name,': Installs = ', installs,)
# Out:
#  Popular apps in COMMUNICATION
#
# WhatsApp Messenger : Installs =  1000000000.0
# Messenger for SMS : Installs =  10000000.0
# My Tele2 : Installs =  5000000.0
# imo beta free calls and text : Installs =  100000000.0
# Contacts : Installs =  50000000.0
# Call Free – Free Call : Installs =  5000000.0
# Web Browser & Explorer : Installs =  5000000.0
# Browser 4G : Installs =  10000000.0
# MegaFon Dashboard : Installs =  10000000.0
# ZenUI Dialer & Contacts : Installs =  10000000.0
# Cricket Visual Voicemail : Installs =  10000000.0
# TracFone My Account : Installs =  1000000.0
# Xperia Link™ : Installs =  10000000.0
# TouchPal Keyboard - Fun Emoji & Android Keyboard : Installs =  10000000.0
# Skype Lite - Free Video Call & Chat : Installs =  5000000.0
# My magenta : Installs =  1000000.0
# Android Messages : Installs =  100000000.0
# Google Duo - High Quality Video Calls : Installs =  500000000.0
# Seznam.cz : Installs =  1000000.0
# Antillean Gold Telegram (original version) : Installs =  100000.0
# AT&T Visual Voicemail : Installs =  10000000.0
# GMX Mail : Installs =  10000000.0
# Omlet Chat : Installs =  10000000.0
# My Vodacom SA : Installs =  5000000.0
# Microsoft Edge : Installs =  5000000.0
# Messenger – Text and Video Chat for Free : Installs =  1000000000.0
# imo free video calls and chat : Installs =  500000000.0
# Calls & Text by Mo+ : Installs =  5000000.0
# free video calls and chat : Installs =  50000000.0
# Skype - free IM & video calls : Installs =  1000000000.0
# Who : Installs =  100000000.0
# GO SMS Pro - Messenger, Free Themes, Emoji : Installs =  100000000.0
# Messaging+ SMS, MMS Free : Installs =  1000000.0
# chomp SMS : Installs =  10000000.0
# Glide - Video Chat Messenger : Installs =  10000000.0
# Text SMS : Installs =  10000000.0
# Talkray - Free Calls & Texts : Installs =  10000000.0
# LINE: Free Calls & Messages : Installs =  500000000.0
# GroupMe : Installs =  10000000.0
# mysms SMS Text Messaging Sync : Installs =  1000000.0
# 2ndLine - Second Phone Number : Installs =  1000000.0
# Google Chrome: Fast & Secure : Installs =  1000000000.0
# Firefox Browser fast & private : Installs =  100000000.0
# Ninesky Browser : Installs =  1000000.0
# Dolphin Browser - Fast, Private & Adblock🐬 : Installs =  50000000.0
# UC Browser - Fast Download Private & Secure : Installs =  500000000.0
# Ghostery Privacy Browser : Installs =  1000000.0
# InBrowser - Incognito Browsing : Installs =  1000000.0
# Lightning Web Browser : Installs =  500000.0
# Web Browser : Installs =  500000.0
# Contacts+ : Installs =  10000000.0
# ExDialer - Dialer & Contacts : Installs =  10000000.0
# PHONE for Google Voice & GTalk : Installs =  1000000.0
# Safest Call Blocker : Installs =  1000000.0
# Full Screen Caller ID : Installs =  5000000.0
# Hiya - Caller ID & Block : Installs =  10000000.0
# Mr. Number-Block calls & spam : Installs =  10000000.0
# Should I Answer? : Installs =  1000000.0
# RocketDial Dialer & Contacts : Installs =  1000000.0
# CIA - Caller ID & Call Blocker : Installs =  5000000.0
# Calls Blacklist - Call Blocker : Installs =  10000000.0
# Call Control - Call Blocker : Installs =  5000000.0
# True Contact - Real Caller ID : Installs =  1000000.0
# Video Caller Id : Installs =  1000000.0
# Sync.ME – Caller ID & Block : Installs =  5000000.0
# Burner - Free Phone Number : Installs =  1000000.0
# Caller ID + : Installs =  1000000.0
# Gmail : Installs =  1000000000.0
# K-9 Mail : Installs =  5000000.0
# myMail – Email for Hotmail, Gmail and Outlook Mail : Installs =  10000000.0
# Email TypeApp - Mail App : Installs =  1000000.0
# All Email Providers : Installs =  1000000.0
# Newton Mail - Email App for Gmail, Outlook, IMAP : Installs =  1000000.0
# GO Notifier : Installs =  10000000.0
# Mail.Ru - Email App : Installs =  50000000.0
# Mail1Click - Secure Mail : Installs =  10000.0
# Daum Mail - Next Mail : Installs =  5000000.0
# mail.com mail : Installs =  1000000.0
# SolMail - All-in-One email app : Installs =  500000.0
# Hangouts : Installs =  1000000000.0
# Vonage Mobile® Call Video Text : Installs =  1000000.0
# JusTalk - Free Video Calls and Fun Video Chat : Installs =  5000000.0
# Azar : Installs =  50000000.0
# LokLok: Draw on a Lock Screen : Installs =  500000.0
# Discord - Chat for Gamers : Installs =  10000000.0
# Messenger Lite: Free Calls & Messages : Installs =  100000000.0
# AntennaPict β : Installs =  1000000.0
# Talkatone: Free Texts, Calls & Phone Number : Installs =  10000000.0
# Kik : Installs =  100000000.0
# K-@ Mail - Email App : Installs =  100000.0
# KakaoTalk: Free Calls & Text : Installs =  100000000.0
# K-9 Material (unofficial) : Installs =  5000.0
# M star Dialer : Installs =  100000.0
# Free WiFi Connect : Installs =  10000000.0
# m:go BiH : Installs =  10000.0
# N-Com Wizard : Installs =  50000.0
# Opera Mini - fast web browser : Installs =  100000000.0
# Opera Browser: Fast and Secure : Installs =  100000000.0
# Opera Mini browser beta : Installs =  10000000.0
# Psiphon Pro - The Internet Freedom VPN : Installs =  10000000.0
# ICQ — Video Calls & Chat Messenger : Installs =  10000000.0
# Telegram : Installs =  100000000.0
# AT&T Messages for Tablet : Installs =  1000000.0
# T-Mobile DIGITS : Installs =  100000.0
# Truecaller: Caller ID, SMS spam blocking & Dialer : Installs =  100000000.0
# Portable Wi-Fi hotspot : Installs =  10000000.0
# AT&T Call Protect : Installs =  5000000.0
# U - Webinars, Meetings & Messenger : Installs =  500000.0
# UC Browser Mini -Tiny Fast Private & Secure : Installs =  100000000.0
# /u/app : Installs =  10000.0
# [verify-U] VideoIdent : Installs =  10000.0
# Viber Messenger : Installs =  500000000.0
# WeChat : Installs =  100000000.0
# WhatsApp Business : Installs =  10000000.0
# WhatsCall Free Global Phone Call App & Cheap Calls : Installs =  10000000.0
# X Browser : Installs =  50000.0
# Yahoo Mail – Stay Organized : Installs =  100000000.0
# Free Adblocker Browser - Adblock & Popup Blocker : Installs =  10000000.0
# Adblock Browser for Android : Installs =  10000000.0
# CM Browser - Ad Blocker , Fast Download , Privacy : Installs =  50000000.0
# Adblock Plus for Samsung Internet - Browse safe. : Installs =  1000000.0
# Ad Blocker Turbo - Adblocker Browser : Installs =  10000.0
# Brave Browser: Fast AdBlocker : Installs =  5000000.0
# AG Contacts, Lite edition : Installs =  5000.0
# Oklahoma Ag Co-op Council : Installs =  10.0
# Bee'ah Employee App : Installs =  100.0
# tournaments and more.aj.2 : Installs =  100.0
# Aj.Petra : Installs =  100.0
# AK Phone : Installs =  5000.0
# PlacarTv Futebol Ao Vivo : Installs =  100000.0
# WiFi Access Point (hotspot) : Installs =  100000.0
# Access Point Names : Installs =  10000.0
# Puffin Web Browser : Installs =  10000000.0
# ClanHQ : Installs =  10000.0
# Ear Agent: Super Hearing : Installs =  5000000.0
# Google Voice : Installs =  10000000.0
# Google Allo : Installs =  10000000.0
# AU Call Blocker - Block Unwanted Calls Texts 2018 : Installs =  1000.0
# Baby Monitor AV : Installs =  100000.0
# AV Phone : Installs =  1000.0
# AW - free video calls and chat : Installs =  1000000.0
# Katalogen.ax : Installs =  100.0
# AZ Browser. Private & Download : Installs =  100000.0
# BA SALES : Installs =  1.0
# BD Data Plan (3G & 4G) : Installs =  500000.0
# BD Internet Packages (Updated) : Installs =  50000.0
# BD Dialer : Installs =  10000.0
# BD Live Call : Installs =  5000.0
# Best Browser BD social networking : Installs =  10.0
# Traffic signs BD : Installs =  500.0
# BF Browser by Betfilter - Stop Gambling Today! : Installs =  10000.0
# My BF App : Installs =  50000.0
# BH Mail : Installs =  1000.0
# Zalo – Video Call : Installs =  50000000.0
# BJ - Confidential : Installs =  10.0
# BK Chat : Installs =  1000.0
# Of the wall Arapaho bk : Installs =  5.0
# AC-BL : Installs =  50.0
# BBM - Free Calls & Messages : Installs =  100000000.0
# DMR BrandMeister Tool : Installs =  10000.0
# BBMoji - Your personalized BBM Stickers : Installs =  1000000.0
# BN MALLORCA Radio : Installs =  1000.0
# BQ Partners : Installs =  1000.0
# BS-Mobile : Installs =  50.0
# ATC Unico BS : Installs =  500.0
# BT One Voice mobile access : Installs =  5000.0
# BT Messenger : Installs =  50000.0
# BT One Phone Mobile App : Installs =  10000.0
# SW-100.tch by Callstel : Installs =  1000000.0
# BT MeetMe with Dolby Voice : Installs =  100000.0
# Bluetooth Auto Connect : Installs =  5000000.0
# AudioBT: BT audio GPS/SMS/Text : Installs =  50000.0
# BV : Installs =  100.0
# Feel Performer : Installs =  10000.0
# Tiny Call Confirm : Installs =  1000000.0
# CB Radio Chat - for friends! : Installs =  1000000.0
# CB On Mobile : Installs =  100000.0
# Virtual Walkie Talkie : Installs =  1000000.0
# Channel 19 : Installs =  100000.0
# Cb browser : Installs =  50.0
# CF Chat: Connecting Friends : Installs =  100.0
# retteMi.ch : Installs =  5000.0
# Chrome Dev : Installs =  5000000.0
# CJ Browser - Fast & Private : Installs =  100.0
# CJ DVD Rentals : Installs =  100.0
# CK Call NEW : Installs =  10.0
# CM Transfer - Share any files with friends nearby : Installs =  5000000.0
# mail.co.uk Mail : Installs =  5000.0
# ClanPlay: Community and Tools for Gamers : Installs =  1000000.0
# CQ-Mobile : Installs =  1000.0
# CQ-Alert : Installs =  500.0
# QRZ Assistant : Installs =  100000.0
# Pocket Prefix Plus : Installs =  10000.0
# Ham Radio Prefixes : Installs =  10000.0
# CS Customizer : Installs =  1000.0
# CS Browser | #1 & BEST BROWSER : Installs =  1000.0
# CS Browser Beta : Installs =  5000.0
# My Vodafone (GR) : Installs =  1000000.0
# IZ2UUF Morse Koch CW : Installs =  50000.0
# C W Browser : Installs =  100.0
# CW Bluetooth SPP : Installs =  100.0
# CW BLE Peripheral Simulator : Installs =  500.0
# Morse Code Reader : Installs =  100000.0
# Learn Morse Code - G0HYN Learn Morse : Installs =  5000.0
# Ring : Installs =  10000.0
# Hyundai CX Conference : Installs =  50.0
# Cy Messenger : Installs =  100.0
# Amadeus GR & CY : Installs =  100.0
# Hlášenírozhlasu.cz : Installs =  10.0
# SMS Sender - sluzba.cz : Installs =  1000.0
# WEB.DE Mail : Installs =  10000000.0
# Your Freedom VPN Client : Installs =  5000000.0
# CallApp: Caller ID, Blocker & Phone Call Recorder : Installs =  10000000.0
# Rádio Sol Nascente DF : Installs =  500.0
# DG Card : Installs =  100.0
# Whoscall - Caller ID & Block : Installs =  10000000.0
# DK Browser : Installs =  10.0
# cluster.dk : Installs =  1000.0
# DK TEL Dialer : Installs =  50.0
# DM for WhatsApp : Installs =  5000.0
# DM Talk New : Installs =  5000.0
# DM - The Offical Messaging App : Installs =  10.0
# DM Tracker : Installs =  1000.0
# Call Blocker & Blacklist : Installs =  1000.0
# ReadyOp DT : Installs =  1000.0
# DU Browser—Browse fast & fun : Installs =  10000000.0
# Caller ID & Call Block - DU Caller : Installs =  5000000.0
# BlueDV AMBE : Installs =  1000.0
# DW Contacts & Phone & Dialer : Installs =  1000000.0
# Deaf World DW : Installs =  10000.0
# Ham DX Cluster & Spots Finder : Installs =  5000.0
# Mircules DX Cluster Lite : Installs =  5000.0
# 3G DZ Configuration : Installs =  50000.0
# chat dz : Installs =  100.0
# love sms good morning : Installs =  5000.0
# Goodbox - Mega App : Installs =  100000.0
# Call Blocker - Blacklist, SMS Blocker : Installs =  1000000.0
# [EF]ShoutBox : Installs =  100.0
# Eg Call : Installs =  10000.0
# ei : Installs =  10.0
# EJ messenger : Installs =  10.0
# Ek IRA : Installs =  10.0
# Orfox: Tor Browser for Android : Installs =  10000000.0
# EO Mumbai : Installs =  10.0
# EP RSS Reader : Installs =  100.0
# Voxer Walkie Talkie Messenger : Installs =  10000000.0
# ES-1 : Installs =  500.0
# Hangouts Dialer - Call Phones : Installs =  10000000.0
# EU Council : Installs =  1000.0
# Council Voting Calculator : Installs =  5000.0
# Have your say on Europe : Installs =  500.0
# Programi podrške EU : Installs =  100.0
# Inbox.eu : Installs =  10000.0
# Web Browser for Android : Installs =  1000000.0
# Everbridge : Installs =  100000.0
# Best Auto Call Recorder Free : Installs =  500.0
# EZ Wifi Notification : Installs =  10000.0
# Test Server SMS FA : Installs =  5.0
# Lite for Facebook Messenger : Installs =  1000000.0
# FC Browser - Focus Privacy Browser : Installs =  1000.0
# EHiN-FH conferenceapp : Installs =  100.0
# Carpooling FH Hagenberg : Installs =  100.0
# Wi-Fi Auto-connect : Installs =  1000000.0
# Talkie - Wi-Fi Calling, Chats, File Sharing : Installs =  500000.0
# WeFi - Free Fast WiFi Connect & Find Wi-Fi Map : Installs =  1000000.0
# Sat-Fi : Installs =  5000.0
# Portable Wi-Fi hotspot Free : Installs =  100000.0
# TownWiFi | Wi-Fi Everywhere : Installs =  500000.0
# Jazz Wi-Fi : Installs =  10000.0
# Sat-Fi Voice : Installs =  1000.0
# Free Wi-fi HotspoT : Installs =  50000.0
# FN Web Radio : Installs =  10.0
# FNH Payment Info : Installs =  10.0
# MARKET FO : Installs =  100.0
# FO OP St-Nazaire : Installs =  100.0
# FO SODEXO : Installs =  100.0
# FO RCBT : Installs =  100.0
# FO Interim : Installs =  100.0
# FO PSA Sept-Fons : Installs =  100.0
# FO AIRBUS TLSE : Installs =  1000.0
# FO STELIA Méaulte : Installs =  100.0
# FO AIRBUS Nantes : Installs =  100.0
# Firefox Focus: The privacy browser : Installs =  1000000.0
# FP Connect : Installs =  100.0
# FreedomPop Messaging Phone/SIM : Installs =  500000.0
# FP Live : Installs =  10.0
# HipChat - beta version : Installs =  50000.0
#
#  Popular apps in VIDEO_PLAYERS
#
# YouTube : Installs =  1000000000.0
# All Video Downloader 2018 : Installs =  1000000.0
# Video Downloader : Installs =  10000000.0
# HD Video Player : Installs =  1000000.0
# Iqiyi (for tablet) : Installs =  1000000.0
# Video Player All Format : Installs =  10000000.0
# Motorola Gallery : Installs =  100000000.0
# Free TV series : Installs =  100000.0
# Video Player All Format for Android : Installs =  500000.0
# VLC for Android : Installs =  100000000.0
# Code : Installs =  10000000.0
# Vote for : Installs =  50000000.0
# XX HD Video downloader-Free Video Downloader : Installs =  1000000.0
# OBJECTIVE : Installs =  1000000.0
# Music - Mp3 Player : Installs =  10000000.0
# HD Movie Video Player : Installs =  1000000.0
# YouCut - Video Editor & Video Maker, No Watermark : Installs =  5000000.0
# Video Editor,Crop Video,Movie Video,Music,Effects : Installs =  1000000.0
# YouTube Studio : Installs =  10000000.0
# video player for android : Installs =  10000000.0
# Vigo Video : Installs =  50000000.0
# Google Play Movies & TV : Installs =  1000000000.0
# HTC Service － DLNA : Installs =  10000000.0
# VPlayer : Installs =  1000000.0
# MiniMovie - Free Video and Slideshow Editor : Installs =  50000000.0
# Samsung Video Library : Installs =  50000000.0
# OnePlus Gallery : Installs =  1000000.0
# LIKE – Magic Video Maker & Community : Installs =  50000000.0
# HTC Service—Video Player : Installs =  5000000.0
# Play Tube : Installs =  1000000.0
# Droid Zap by Motorola : Installs =  5000000.0
# video player : Installs =  1000000.0
# G Guide Program Guide (SOFTBANK EMOBILE WILLCOM version) : Installs =  1000000.0
# Video.Guru - Video Maker : Installs =  1000000.0
# HTC Gallery : Installs =  10000000.0
# PowerDirector Video Editor App: 4K, Slow Mo & More : Installs =  10000000.0
# Cartoon Network App : Installs =  10000000.0
# Video Status : Installs =  1000000.0
# Video Wallpaper Show : Installs =  500.0
# SVT Play : Installs =  1000000.0
# BluTV : Installs =  1000000.0
# Tencent Video - Supporting the whole network : Installs =  1000000.0
# Casper Ssinema : Installs =  10000.0
# amazer - Global Kpop Video Community : Installs =  100000.0
# MX Player : Installs =  500000000.0
# Video Editor : Installs =  5000000.0
# Omlet Arcade - Stream, Meet, Play : Installs =  10000000.0
# VUE: video editor & camcorder : Installs =  1000000.0
# Magisto Video Editor & Maker : Installs =  10000000.0
# Dubsmash : Installs =  100000000.0
# DU Recorder – Screen Recorder, Video Editor, Live : Installs =  50000000.0
# KineMaster – Pro Video Editor : Installs =  50000000.0
# Mobizen Screen Recorder for SAMSUNG : Installs =  10000000.0
# Mobizen Screen Recorder for LG - Record, Capture : Installs =  1000000.0
# M-Sight Pro : Installs =  5000.0
# Sketch 'n' go : Installs =  100000.0
# Q-See Plus : Installs =  5000.0
# Ustream : Installs =  10000000.0
# VMate : Installs =  50000000.0
# All Video Downloader : Installs =  10000000.0
# VidPlay : Installs =  1000000.0
# HD Video Downloader : 2018 Best video mate : Installs =  50000000.0
# VivaVideo - Video Editor & Photo Movie : Installs =  100000000.0
# VideoShow-Video Editor, Video Maker, Beauty Camera : Installs =  100000000.0
# W Box VMS : Installs =  10000.0
# W Box VMS HD : Installs =  5000.0
# AB Repeat Player : Installs =  100000.0
# A-B repeater : Installs =  5000.0
# Ez Screen Recorder (no ad) : Installs =  100000.0
# Adobe Premiere Clip : Installs =  5000000.0
# FilmoraGo - Free Video Editor : Installs =  10000000.0
# ActionDirector Video Editor - Edit Videos Fast : Installs =  5000000.0
# AJ Player : Installs =  100.0
# AK Lodi Films : Installs =  100.0
# WiFi Baby Monitor - NannyCam : Installs =  5000000.0
# Ringdroid : Installs =  50000000.0
# Multiple Videos at Same Time : Installs =  1000000.0
# AV-IPTV : Installs =  1000.0
# HD Video Player (wmv,avi,mp4,flv,av,mpg,mkv)2017 : Installs =  10000.0
# HD Video Player - Video & MP3 Player | AV Player | : Installs =  5000.0
# EML UPnP-AV Control Point : Installs =  10000.0
# AW Screen Recorder No Root : Installs =  100000.0
# AX Player -Nougat Video Player : Installs =  1000000.0
# AX Video Player : Installs =  50000.0
# Ay : Installs =  5000.0
# Ay Sabz Gunbad Waly : Installs =  1000.0
# iMediaShare – Photos & Music : Installs =  10000000.0
# AZ Screen Recorder - No Root : Installs =  10000000.0
# Movie Downloader Torrent : Az Torrent : Installs =  1000.0
# A-Z Screen Recorder - : Installs =  500.0
# BC iptv player : Installs =  1000.0
# Bc Vod : Installs =  100.0
# Funny videos for whatsapp : Installs =  1000000.0
# BG video - floating video - background video : Installs =  5000.0
# BG MUSIC PLAYER - MUSIC PLAYER : Installs =  100.0
# bgtime.tv : Installs =  50000.0
# YourTube Video Views BG : Installs =  500.0
# Music for Youtube - Tube Music BG, Red+ : Installs =  1000.0
# BGCN TV : Installs =  100000.0
# AfreecaTV : Installs =  10000000.0
# BK News Channel : Installs =  10000.0
# BR Video Player : Installs =  5000.0
# BR Series : Installs =  50000.0
# CINE BR : Installs =  1000.0
# iPlayIT for YouTube VR Player : Installs =  1000000.0
# BSPlayer FREE : Installs =  10000000.0
# BSPlayer ARMv7 VFP CPU support : Installs =  1000000.0
# BS player remote : Installs =  10000.0
# BitTorrent®- Torrent Downloads : Installs =  10000000.0
# Bx-WiFi-GI : Installs =  100.0
# BZ Langenthaler Tagblatt : Installs =  1000.0
# Nero AirBurn : Installs =  100000.0
# CI Stream : Installs =  10.0
# CJ Camcorder : Installs =  500.0
# CJ VLC HD Remote (+ Stream) : Installs =  500000.0
# ACTIVEON CX & CX GOLD : Installs =  50000.0
# CX Monthly Tech News : Installs =  500.0
# DG UPnP Player Free : Installs =  10000.0
# DG Screen Recorder : Installs =  500.0
# DG Video Editor : Installs =  10000.0
# Video Downloader - for Instagram Repost App : Installs =  10000000.0
# Quik – Free Video Editor for photos, clips, music : Installs =  10000000.0
# FrostWire: Torrent Downloader & Music Player : Installs =  10000000.0
# Inst Download - Video & Photo : Installs =  10000000.0
# Vuze Torrent Downloader : Installs =  1000000.0
# AndStream - Streaming Download : Installs =  1000000.0
# DR TV : Installs =  500000.0
# DS photo : Installs =  1000000.0
# DS video : Installs =  1000000.0
# DU Privacy-hide apps、sms、file : Installs =  1000000.0
# iSmart DV : Installs =  1000000.0
# dv Prompter : Installs =  50000.0
# DV Lottery Photo : Installs =  5000.0
# MelifeCam-M : Installs =  10000.0
# GoPlus Cam : Installs =  500000.0
# GoAction : Installs =  100000.0
# 4K VIDEO PLAYER ULTRA HD : Installs =  5000.0
# Downvids Helper - One touch DW : Installs =  10000.0
# DZ Popup Video Player : Installs =  5000.0
# EC MANAGER : Installs =  100.0
# EF Sidekick : Installs =  5000.0
# ek tuhi : Installs =  10000.0
# Naruto Shippuden - Watch Free! : Installs =  10000000.0
# ES Audio Player ( Shortcut ) : Installs =  100000.0
# Furrion ES Control : Installs =  5000.0
# ES-IPTV : Installs =  50000.0
# EZCast – Cast Media to TV : Installs =  1000000.0
# EZ Web Video Cast | Chromecast : Installs =  100000.0
# EZ-SEE : Installs =  10000.0
# EZ TV Player : Installs =  10000.0
# EZ Usenet for Easynews® : Installs =  10000.0
# EZ game screen recorder with audio 1080P : Installs =  1000.0
# Videos downloader for Facebook:fast fb video saver : Installs =  5000.0
# Video Downloader for FB : Video Download with Link : Installs =  100000.0
# HD VideoDownlaoder For Fb : XXVideo Downloader : Installs =  10000.0
# HD Video Download for Facebook : Installs =  1000000.0
# Art of F J Taylor : Installs =  10.0
# Motorola FM Radio : Installs =  100000000.0
# List iptv FR : Installs =  100.0
#
#  Popular apps in SOCIAL
#
# Facebook : Installs =  1000000000.0
# Facebook Lite : Installs =  500000000.0
# Tumblr : Installs =  100000000.0
# Social network all in one 2018 : Installs =  100000.0
# Pinterest : Installs =  100000000.0
# TextNow - free text + calls : Installs =  10000000.0
# Google+ : Installs =  1000000000.0
# The Messenger App : Installs =  1000000.0
# Messenger Pro : Installs =  1000000.0
# Free Messages, Video, Chat,Text for Messenger Plus : Installs =  1000000.0
# Telegram X : Installs =  5000000.0
# The Video Messenger App : Installs =  100000.0
# Jodel - The Hyperlocal App : Installs =  1000000.0
# Hide Something - Photo, Video : Installs =  5000000.0
# Love Sticker : Installs =  1000000.0
# Web Browser & Fast Explorer : Installs =  5000000.0
# LiveMe - Video chat, new friends, and make money : Installs =  10000000.0
# VidStatus app - Status Videos & Status Downloader : Installs =  5000000.0
# Love Images : Installs =  1000000.0
# Web Browser ( Fast & Secure Web Explorer) : Installs =  500000.0
# SPARK - Live random video chat & meet new people : Installs =  5000000.0
# Golden telegram : Installs =  50000.0
# Facebook Local : Installs =  1000000.0
# Meet – Talk to Strangers Using Random Video Chat : Installs =  5000000.0
# MobilePatrol Public Safety App : Installs =  1000000.0
# 💘 WhatsLov: Smileys of love, stickers and GIF : Installs =  1000000.0
# HTC Social Plugin - Facebook : Installs =  10000000.0
# Quora : Installs =  10000000.0
# Kate Mobile for VK : Installs =  10000000.0
# Family GPS tracker KidControl + GPS by SMS Locator : Installs =  1000000.0
# Moment : Installs =  1000000.0
# Text Me: Text Free, Call Free, Second Phone Number : Installs =  10000000.0
# Text Free: WiFi Calling App : Installs =  5000000.0
# Badoo - Free Chat & Dating App : Installs =  100000000.0
# Text free - Free Text + Call : Installs =  10000000.0
# Tango - Live Video Broadcast : Installs =  100000000.0
# ooVoo Video Calls, Messaging & Stories : Installs =  50000000.0
# Whisper : Installs =  5000000.0
# Blogger : Installs =  5000000.0
# Bloglovin' : Installs =  500000.0
# Blogaway for Android (Blogger) : Installs =  100000.0
# Instagram : Installs =  1000000000.0
# TwitCasting Live : Installs =  1000000.0
# Stream - Live Video Community : Installs =  500000.0
# YouNow: Live Stream Video Chat : Installs =  10000000.0
# Mirrativ: Live Stream Any App : Installs =  500000.0
# Snapchat : Installs =  500000000.0
# Banjo : Installs =  1000000.0
# We Heart It : Installs =  10000000.0
# MeetMe: Chat & Meet New People : Installs =  50000000.0
# Timehop : Installs =  5000000.0
# Frontback - Social Photos : Installs =  1000000.0
# LinkedIn : Installs =  100000000.0
# Path : Installs =  10000000.0
# SayHi Chat, Meet New People : Installs =  10000000.0
# Tapatalk - 100,000+ Forums : Installs =  10000000.0
# Couple - Relationship App : Installs =  1000000.0
# Nextdoor - Local neighborhood news & classifieds : Installs =  5000000.0
# LOVOO : Installs =  10000000.0
# Jaumo Dating, Flirt & Live Video : Installs =  10000000.0
# Patook - make platonic friends : Installs =  100000.0
# Zello PTT Walkie Talkie : Installs =  50000000.0
# textPlus: Free Text & Calls : Installs =  10000000.0
# magicApp Calling & Messaging : Installs =  10000000.0
# Dating App, Flirt & Chat : W-Match : Installs =  10000000.0
# uCiC- Videos and Photos on demand : Installs =  100000.0
# Meetup : Installs =  5000000.0
# POF Free Dating App : Installs =  50000000.0
# Tagged - Meet, Chat & Dating : Installs =  10000000.0
# SKOUT - Meet, Chat, Go Live : Installs =  50000000.0
# Mico- Stranger Chat Random video Chat, Live, Meet : Installs =  10000000.0
# Waplog - Free Chat, Dating App, Meet Singles : Installs =  10000000.0
# Tik Tok - including musical.ly : Installs =  100000000.0
# B-Messenger Video Chat : Installs =  1000000.0
# BIGO LIVE - Live Stream : Installs =  100000000.0
# Greeting Cards & Wishes : Installs =  500000.0
# Share G - Images Sharing - Wallpapers App : Installs =  10000.0
# H letter images : Installs =  1000.0
# Instachat 😜 : Installs =  5000000.0
# Fame Boom for Real Followers, Likes : Installs =  5000000.0
# FollowMeter for Instagram : Installs =  1000000.0
# Mali J : Installs =  10000.0
# KDRAMA Amino for K-Drama Fans : Installs =  100000.0
# KPOP Amino for K-Pop Entertainment : Installs =  100000.0
# EXO-L Amino for EXO Fans : Installs =  50000.0
# Verdad o Reto : Installs =  500000.0
# pixiv : Installs =  1000000.0
# Join R, Community Engagement : Installs =  1000.0
# U LIVE – Video Chat & Stream : Installs =  1000000.0
# See U - Random video chat, video chat : Installs =  100000.0
# What U See : Installs =  100000.0
# U-Report : Installs =  10000.0
# Meet U - Get Friends for Snapchat, Kik & Instagram : Installs =  100000.0
# VMate Lite - Funny Short Videos Social Network : Installs =  1000000.0
# V Bucks ProTips New : Installs =  1000.0
# i-share AF/KLM (AFKL ishare) : Installs =  100.0
# Eternal Light AG : Installs =  100.0
# Message AI - Write Better Messages (Free) : Installs =  100.0
# Jamaa Amino for Animal Jam : Installs =  10000.0
# Legend - Animate Text in Video : Installs =  10000000.0
# GUYZ - Gay Chat & Gay Dating : Installs =  1000000.0
# eChallan Andhra Pradesh (AP) : Installs =  1000.0
# Snaappy – 3D fun AR core communication platform : Installs =  1000000.0
# Undertale AU Amino : Installs =  50000.0
# Au Pair : Installs =  10000.0
# Media Sosial TNI AU : Installs =  1000.0
# BA 3 Banjarmasin : Installs =  10.0
# iCard BD Plus : Installs =  500.0
# Movement BE : Installs =  100.0
# YAY - TBH : Installs =  100000.0
# Find My Friends : Installs =  10000000.0
# BG LINKED (BGLINKED) : Installs =  1000.0
# Zdravei.BG : Installs =  1000.0
# BGKontakti London BG Kontakti : Installs =  500.0
# BGKontakti Bayern BG Kontakti : Installs =  1000.0
# BGKontakti Vienna BG Kontakti : Installs =  1000.0
# Discípulos em BH : Installs =  100.0
# BH Connect : Installs =  1.0
# Gayvox - Gay Lesbian Bi Dating : Installs =  500000.0
# Grindr - Gay chat : Installs =  10000000.0
# Lesbian Chat & Dating - SPICY : Installs =  1000000.0
# Alumni BJ : Installs =  100.0
# VK : Installs =  100000000.0
# BK Traffic Control cum Chart : Installs =  10000.0
# Daily Murli Saar Widget : Installs =  10000.0
# Myjob@BM : Installs =  100.0
# bm-Events : Installs =  10.0
# BOO! - Next Generation Messenger : Installs =  1000000.0
# Wishbone - Compare Anything : Installs =  1000000.0
# BR Chat Bot : Installs =  1000.0
# Br Browser : Installs =  500.0
# Dr B R Ambedkar (Jai Bhim) : Installs =  100000.0
# Dr. B.R.Ambedkar : Installs =  100000.0
# Black Social : Installs =  1000.0
# BT Communicator : Installs =  10000.0
# BT Dating -Find your match, help cupid, be social : Installs =  50000.0
# Fiesta by Tango - Find, Meet and Make New Friends : Installs =  1000000.0
# Evasion.bz : Installs =  100.0
# CB Heroes : Installs =  5.0
# CG Districts : Installs =  1000.0
# Digi-TV.ch : Installs =  10000.0
# Students.ch : Installs =  1000.0
# CJ Gospel Hour : Installs =  100.0
# Pekalongan CJ : Installs =  0.0
# Hashtags For Likes.co : Installs =  50000.0
# CP Dialer : Installs =  50000.0
# C.P. CERVANTES (TOBARRA) : Installs =  5.0
# Cyprus Police : Installs =  10000.0
# Rande.cz : Installs =  50000.0
# signály.cz : Installs =  1000.0
# DB Event App : Installs =  5000.0
# DC Comics Amino : Installs =  1000.0
# DF BugMeNot : Installs =  500.0
# Noticias DF : Installs =  1000.0
# Periscope - Live Video : Installs =  10000000.0
# Daddyhunt: Gay Dating : Installs =  500000.0
# Free phone calls, free texting SMS on free number : Installs =  10000000.0
# Phone Tracker : Family Locator : Installs =  10000000.0
# HOLLA Live: Meet New People via Random Video Chat : Installs =  5000000.0
# Dating.dk : Installs =  100000.0
# DK Murali : Installs =  500.0
# GirlTalk.dk : Installs =  100.0
# +Download 4 Instagram Twitter : Installs =  1000000.0
# DM Me - Chat : Installs =  10000.0
# DM for IG 😘 - Image & Video Saver for Instagram : Installs =  5000.0
# Auto DM for Twitter 🔥 : Installs =  1000.0
# DM Storage (for twitter) : Installs =  100.0
# Fake Chat (Direct Message) : Installs =  500000.0
# Otto DM : Installs =  10.0
# DN Blog : Installs =  10.0
# DP and Status for WhatsApp 2018 : Installs =  100000.0
# Dp For Whatsapp : Installs =  5000.0
# Profile Pictures and DP for Whatsapp : Installs =  5000.0
# Dp for Facebook : Installs =  5000.0
# Best DP and Status : Installs =  10000.0
# Instant DP Downloader for Instagram : Installs =  5000.0
# DP Display Pictures Life Quotes Motivational GM : Installs =  5000.0
# Qeek for Instagram - Zoom profile insta DP : Installs =  500000.0
# DV Statistics : Installs =  100.0
# DW Streaming : Installs =  1000.0
# News Dz : Installs =  10.0
# quran-DZ : Installs =  10.0
# TN e Sevai TN EB Bill Patta Citta EC Birth All Hub : Installs =  5000.0
# TNEB Bill Online Payment (Tamil) : Installs =  5000.0
# UP EB Bill Payment & Details : Installs =  50.0
# TN EC Online New : Installs =  1000.0
# TN Patta /Chitta /EC New : Installs =  100.0
# EG Way Life : Installs =  50.0
# Equestria Amino for MLP : Installs =  50000.0
# Ek Maratha : Installs =  10000.0
# Hum Ek Hain 2.02 : Installs =  10.0
# Sabka Malik Ek Sai : Installs =  1000.0
# EO RAIPUR : Installs =  10.0
# Anime et Manga Amino en Français : Installs =  50000.0
# Hornet - Gay Social Network : Installs =  5000000.0
# Amino: Communities and Chats : Installs =  10000000.0
# European Solidarity Corps : Installs =  1000.0
# Reisedealz.eu : Installs =  10.0
# Eddsworld Amino : Installs =  10000.0
# Rejoin Your Ex : Installs =  100.0
# Amleen Ey : Installs =  1.0
# Coupe Adhémar EY 2017 : Installs =  50.0
# EZ Video Download for Facebook : Installs =  1000000.0
# Messages, Text and Video Chat for Messenger : Installs =  10000000.0
# All Social Networks : Installs =  1000000.0
# Messenger Messenger : Installs =  10000000.0
# Facebook Creator : Installs =  1000000.0
# Swift for Facebook Lite : Installs =  500000.0
# Friendly for Facebook : Installs =  1000000.0
# Faster for Facebook Lite : Installs =  1000000.0
# Puffin for Facebook : Installs =  500000.0
# Profile Tracker - Who Viewed My Facebook Profile : Installs =  500000.0
# Pink Color for Facebook : Installs =  500000.0
# Messenger : Installs =  10000000.0
# Stickers for Imo, fb, whatsapp : Installs =  10000.0
# Who Viewed My Facebook Profile - Stalkers Visitors : Installs =  5000000.0
# Downloader plus for FB : Installs =  500.0
# MB Notifications for FB (Free) : Installs =  100000.0
# Phoenix - Facebook & Messenger : Installs =  100000.0
# Faster Social for Facebook : Installs =  100000.0
# Check Your Visitors on FB ? : Installs =  5000.0
# Stickers for Facebook : Installs =  1000000.0
# Lite Messenger for Facebook Lite : Installs =  10000.0
# Mini for Facebook lite : Installs =  10000.0
# FB Advanced Search : Installs =  50.0
# funny Image Comments for FB : Installs =  5000.0
# Unlimited Group Links - Whatsapp, FB, Telegram : Installs =  10000.0
# FCB Connect - FC Barcelona : Installs =  50000.0
# Frases Cristianas de Esperanza y Fe : Installs =  100.0
# FutureNet your social app : Installs =  100000.0
# Alarm.fo – choose your info : Installs =  1000.0
# FunForMobile Ringtones & Chat : Installs =  5000000.0
# Chat For Strangers - Video Chat : Installs =  100000.0
# Fr Daoud Lamei : Installs =  100000.0
# Naruto & Boruto FR : Installs =  100.0
# Frim: get new friends on local chat rooms : Installs =  5000000.0
#
#  Popular apps in BOOKS_AND_REFERENCE
#
# E-Book Read - Read Book for free : Installs =  50000.0
# Download free book with green book : Installs =  100000.0
# Wikipedia : Installs =  10000000.0
# Cool Reader : Installs =  10000000.0
# Free Panda Radio Music : Installs =  100000.0
# Book store : Installs =  1000000.0
# FBReader: Favorite Book Reader : Installs =  10000000.0
# English Grammar Complete Handbook : Installs =  500000.0
# Free Books - Spirit Fanfiction and Stories : Installs =  1000000.0
# Google Play Books : Installs =  1000000000.0
# AlReader -any text book reader : Installs =  5000000.0
# Offline English Dictionary : Installs =  100000.0
# Offline: English to Tagalog Dictionary : Installs =  500000.0
# FamilySearch Tree : Installs =  1000000.0
# Cloud of Books : Installs =  1000000.0
# Recipes of Prophetic Medicine for free : Installs =  500000.0
# ReadEra – free ebook reader : Installs =  1000000.0
# Anonymous caller detection : Installs =  10000.0
# Ebook Reader : Installs =  5000000.0
# Litnet - E-books : Installs =  100000.0
# Read books online : Installs =  5000000.0
# English to Urdu Dictionary : Installs =  500000.0
# eBoox: book reader fb2 epub zip : Installs =  1000000.0
# English Persian Dictionary : Installs =  500000.0
# Flybook : Installs =  500000.0
# All Maths Formulas : Installs =  1000000.0
# Ancestry : Installs =  5000000.0
# HTC Help : Installs =  10000000.0
# English translation from Bengali : Installs =  100000.0
# Pdf Book Download - Read Pdf Book : Installs =  100000.0
# Free Book Reader : Installs =  100000.0
# eBoox new: Reader for fb2 epub zip books : Installs =  50000.0
# Only 30 days in English, the guideline is guaranteed : Installs =  500000.0
# Moon+ Reader : Installs =  10000000.0
# SH-02J Owner's Manual (Android 8.0) : Installs =  50000.0
# English-Myanmar Dictionary : Installs =  1000000.0
# Golden Dictionary (EN-AR) : Installs =  1000000.0
# All Language Translator Free : Installs =  1000000.0
# Azpen eReader : Installs =  500000.0
# URBANO V 02 instruction manual : Installs =  100000.0
# Bible : Installs =  100000000.0
# C Programs and Reference : Installs =  50000.0
# C Offline Tutorial : Installs =  1000.0
# C Programs Handbook : Installs =  50000.0
# Amazon Kindle : Installs =  100000000.0
# Aab e Hayat Full Novel : Installs =  100000.0
# Aldiko Book Reader : Installs =  10000000.0
# Google I/O 2018 : Installs =  500000.0
# R Language Reference Guide : Installs =  10000.0
# Learn R Programming Full : Installs =  5000.0
# R Programing Offline Tutorial : Installs =  1000.0
# Guide for R Programming : Installs =  5.0
# Learn R Programming : Installs =  10.0
# R Quick Reference Big Data : Installs =  1000.0
# V Made : Installs =  100000.0
# Wattpad 📖 Free Books : Installs =  100000000.0
# Dictionary - WordWeb : Installs =  5000000.0
# Guide (for X-MEN) : Installs =  100000.0
# AC Air condition Troubleshoot,Repair,Maintenance : Installs =  5000.0
# AE Bulletins : Installs =  1000.0
# Ae Allah na Dai (Rasa) : Installs =  10000.0
# 50000 Free eBooks & Free AudioBooks : Installs =  5000000.0
# Ag PhD Field Guide : Installs =  10000.0
# Ag PhD Deficiencies : Installs =  10000.0
# Ag PhD Planting Population Calculator : Installs =  1000.0
# Ag PhD Soybean Diseases : Installs =  1000.0
# Fertilizer Removal By Crop : Installs =  50000.0
# A-J Media Vault : Installs =  50.0
# Al-Quran (Free) : Installs =  10000000.0
# Al Quran (Tafsir & by Word) : Installs =  500000.0
# Al Quran Indonesia : Installs =  10000000.0
# Al'Quran Bahasa Indonesia : Installs =  10000000.0
# Al Quran Al karim : Installs =  1000000.0
# Al-Muhaffiz : Installs =  50000.0
# Al Quran : EAlim - Translations & MP3 Offline : Installs =  5000000.0
# Al-Quran 30 Juz free copies : Installs =  500000.0
# Koran Read &MP3 30 Juz Offline : Installs =  1000000.0
# Hafizi Quran 15 lines per page : Installs =  1000000.0
# Quran for Android : Installs =  10000000.0
# Surah Al-Waqiah : Installs =  100000.0
# Hisnul Al Muslim - Hisn Invocations & Adhkaar : Installs =  100000.0
# Satellite AR : Installs =  1000000.0
# Audiobooks from Audible : Installs =  100000000.0
# Kinot & Eichah for Tisha B'Av : Installs =  10000.0
# AW Tozer Devotionals - Daily : Installs =  5000.0
# Tozer Devotional -Series 1 : Installs =  1000.0
# The Pursuit of God : Installs =  1000.0
# AY Sing : Installs =  5000.0
# Ay Hasnain k Nana Milad Naat : Installs =  10000.0
# Ay Mohabbat Teri Khatir Novel : Installs =  10000.0
# Arizona Statutes, ARS (AZ Law) : Installs =  1000.0
# Oxford A-Z of English Usage : Installs =  1000000.0
# BD Fishpedia : Installs =  1000.0
# BD All Sim Offer : Installs =  10000.0
# Youboox - Livres, BD et magazines : Installs =  500000.0
# B&H Kids AR : Installs =  10000.0
# B y H Niños ES : Installs =  5000.0
# Dictionary.com: Find Definitions for English Words : Installs =  10000000.0
# English Dictionary - Offline : Installs =  10000000.0
# Bible KJV : Installs =  5000000.0
# Borneo Bible, BM Bible : Installs =  10000.0
# MOD Black for BM : Installs =  100.0
# BM Box : Installs =  1000.0
# Anime Mod for BM : Installs =  100.0
# NOOK: Read eBooks & Magazines : Installs =  10000000.0
# NOOK Audiobooks : Installs =  500000.0
# NOOK App for NOOK Devices : Installs =  500000.0
# Browsery by Barnes & Noble : Installs =  5000.0
# bp e-store : Installs =  1000.0
# Brilliant Quotes: Life, Love, Family & Motivation : Installs =  1000000.0
# BR Ambedkar Biography & Quotes : Installs =  10000.0
# BU Alsace : Installs =  100.0
# Catholic La Bu Zo Kam : Installs =  500.0
# Khrifa Hla Bu (Solfa) : Installs =  10.0
# Kristian Hla Bu : Installs =  10000.0
# SA HLA BU : Installs =  1000.0
# Learn SAP BW : Installs =  500.0
# Learn SAP BW on HANA : Installs =  500.0
# CA Laws 2018 (California Laws and Codes) : Installs =  5000.0
# Bootable Methods(USB-CD-DVD) : Installs =  10000.0
# cloudLibrary : Installs =  100000.0
# SDA Collegiate Quarterly : Installs =  500.0
# Sabbath School : Installs =  100000.0
# Cypress College Library : Installs =  100.0
# Stats Royale for Clash Royale : Installs =  1000000.0
# GATE 21 years CS Papers(2011-2018 Solved) : Installs =  50.0
# Learn CT Scan Of Head : Installs =  5000.0
# Easy Cv maker 2018 : Installs =  10000.0
# How to Write CV : Installs =  100000.0
# CW Nuclear : Installs =  1000.0
# CY Spray nozzle : Installs =  10.0
# BibleRead En Cy Zh Yue : Installs =  5.0
# CZ-Help : Installs =  5.0
# Modlitební knížka CZ : Installs =  500.0
# Guide for DB Xenoverse : Installs =  10000.0
# Guide for DB Xenoverse 2 : Installs =  10000.0
# Guide for IMS DB : Installs =  10.0
# DC HSEMA : Installs =  5000.0
# DC Public Library : Installs =  1000.0
# Painting Lulu DC Super Friends : Installs =  1000.0
# Dictionary : Installs =  10000000.0
# Fix Error Google Playstore : Installs =  1000.0
# D. H. Lawrence Poems FREE : Installs =  1000.0
# Bilingual Dictionary Audio App : Installs =  5000.0
# DM Screen : Installs =  10000.0
# wikiHow: how to do anything : Installs =  1000000.0
# Dr. Doug's Tips : Installs =  1000.0
# Bible du Semeur-BDS (French) : Installs =  50000.0
# La citadelle du musulman : Installs =  50000.0
# DV 2019 Entry Guide : Installs =  10000.0
# DV 2019 - EDV Photo & Form : Installs =  50000.0
# DV 2018 Winners Guide : Installs =  1000.0
# EB Annual Meetings : Installs =  1000.0
# EC - AP & Telangana : Installs =  5000.0
# TN Patta Citta & EC : Installs =  10000.0
# AP Stamps and Registration : Installs =  10000.0
# CompactiMa EC pH Calibration : Installs =  100.0
# EGW Writings 2 : Installs =  100000.0
# EGW Writings : Installs =  1000000.0
# Bible with EGW Comments : Installs =  100000.0
# My Little Pony AR Guide : Installs =  1000000.0
# SDA Sabbath School Quarterly : Installs =  500000.0
# Duaa Ek Ibaadat : Installs =  5000.0
# Spanish English Translator : Installs =  10000000.0
# Dictionary - Merriam-Webster : Installs =  10000000.0
# JW Library : Installs =  10000000.0
# Oxford Dictionary of English : Free : Installs =  10000000.0
# English Hindi Dictionary : Installs =  10000000.0
# English to Hindi Dictionary : Installs =  5000000.0
# EP Research Service : Installs =  1000.0
# Hymnes et Louanges : Installs =  100000.0
# EU Charter : Installs =  1000.0
# EU Data Protection : Installs =  1000.0
# EU IP Codes : Installs =  100.0
# EW PDF : Installs =  5.0
# BakaReader EX : Installs =  100000.0
# EZ Quran : Installs =  50000.0
# FA Part 1 & 2 Past Papers Solved Free – Offline : Installs =  5000.0
# La Fe de Jesus : Installs =  1000.0
# La Fe de Jesús : Installs =  500.0
# Le Fe de Jesus : Installs =  500.0
# Florida - Pocket Brainbook : Installs =  1000.0
# Florida Statutes (FL Code) : Installs =  1000.0
# English To Shona Dictionary : Installs =  10000.0
# Greek Bible FP (Audio) : Installs =  1000.0
# Golden Dictionary (FR-AR) : Installs =  500000.0
# Fanfic-FR : Installs =  5000.0
# Bulgarian French Dictionary Fr : Installs =  10000.0
# Chemin (fr) : Installs =  1000.0
# The SCP Foundation DB fr nn5n : Installs =  1000.0

# %% [markdown]
# #### Findings after Analysis
#
# * Again there is a monopoly in sectors like `COMMUNICATION`,`VIDEO_PLAYERS`,`SOCIAL`.
#
# * `Book` genre showed promise in the iOS platform. We will check the same genre in Google Play Store `BOOK_AND_REFERENCE`.

# %%
for app in playstore_final:
    if app[1] == 'BOOKS_AND_REFERENCE' and (app[5] == '1,000,000,000+'
                                            or app[5] == '500,000,000+'
                                            or app[5] == '100,000,000+'):
        print(app[0], ':', app[5])
# Out:
# Google Play Books : 1,000,000,000+
# Bible : 100,000,000+
# Amazon Kindle : 100,000,000+
# Wattpad 📖 Free Books : 100,000,000+
# Audiobooks from Audible : 100,000,000+

# %% [markdown]
# Not many apps dominating the this genre. There are only a few apps that have a high number of installs.
# We can look at the type of apps that are somewhere in the mid-popularity of this niche. If those apps also have significant traffic, this would mean the sector is not saturated by the big players. We can them aim to develop an app similar to those in the mid-popularity range. Ensuring a good enough revenue and traffic through our desired business model.

# %%
for app in playstore_final:
    if app[1] == 'BOOKS_AND_REFERENCE' and (app[5] == '1,000,000+'
                                            or app[5] == '5,000,000+'
                                            or app[5] == '10,000,000+'
                                            or app[5] == '50,000,000+'):
        print(app[0], ':', app[5])
# Out:
# Wikipedia : 10,000,000+
# Cool Reader : 10,000,000+
# Book store : 1,000,000+
# FBReader: Favorite Book Reader : 10,000,000+
# Free Books - Spirit Fanfiction and Stories : 1,000,000+
# AlReader -any text book reader : 5,000,000+
# FamilySearch Tree : 1,000,000+
# Cloud of Books : 1,000,000+
# ReadEra – free ebook reader : 1,000,000+
# Ebook Reader : 5,000,000+
# Read books online : 5,000,000+
# eBoox: book reader fb2 epub zip : 1,000,000+
# All Maths Formulas : 1,000,000+
# Ancestry : 5,000,000+
# HTC Help : 10,000,000+
# Moon+ Reader : 10,000,000+
# English-Myanmar Dictionary : 1,000,000+
# Golden Dictionary (EN-AR) : 1,000,000+
# All Language Translator Free : 1,000,000+
# Aldiko Book Reader : 10,000,000+
# Dictionary - WordWeb : 5,000,000+
# 50000 Free eBooks & Free AudioBooks : 5,000,000+
# Al-Quran (Free) : 10,000,000+
# Al Quran Indonesia : 10,000,000+
# Al'Quran Bahasa Indonesia : 10,000,000+
# Al Quran Al karim : 1,000,000+
# Al Quran : EAlim - Translations & MP3 Offline : 5,000,000+
# Koran Read &MP3 30 Juz Offline : 1,000,000+
# Hafizi Quran 15 lines per page : 1,000,000+
# Quran for Android : 10,000,000+
# Satellite AR : 1,000,000+
# Oxford A-Z of English Usage : 1,000,000+
# Dictionary.com: Find Definitions for English Words : 10,000,000+
# English Dictionary - Offline : 10,000,000+
# Bible KJV : 5,000,000+
# NOOK: Read eBooks & Magazines : 10,000,000+
# Brilliant Quotes: Life, Love, Family & Motivation : 1,000,000+
# Stats Royale for Clash Royale : 1,000,000+
# Dictionary : 10,000,000+
# wikiHow: how to do anything : 1,000,000+
# EGW Writings : 1,000,000+
# My Little Pony AR Guide : 1,000,000+
# Spanish English Translator : 10,000,000+
# Dictionary - Merriam-Webster : 10,000,000+
# JW Library : 10,000,000+
# Oxford Dictionary of English : Free : 10,000,000+
# English Hindi Dictionary : 10,000,000+
# English to Hindi Dictionary : 5,000,000+

# %% [markdown]
# Apart from Dictionaries and other popular book apps like the Bible and Qur'an, there are plenty of apps with Book reading software and ePDFs that have a uniform number of downloads.

# %% [markdown]
# ## Conclusion
#
# We looked through the different genres and were able to find one niche which shows promise. We can thus conclude that an app based around book reading, whether a single book or multiple ones, with a simplistic and fluid GUI can gain popularity and have significant user traffic for our company to benefit from ads revenue generation. However, it looks like the market is already full of libraries, so we need to add some special features besides the raw version of the book. This might include daily quotes from the book, an audio version of the book, quizzes on the book, a forum where people can discuss the book, etc.
